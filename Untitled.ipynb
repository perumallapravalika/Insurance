# %%
import pandas as pd

ic_df=pd.read_csv('insurance_claims.csv') 
ic_df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0         466132  ...         2                     YES              71610
# 1         468176  ...         0                       ?               5070
# 2         430632  ...         3                      NO              34650
# 3         608117  ...         2                      NO              63400
# 4         610706  ...         1                      NO               6500
# ..           ...  ...       ...                     ...                ...
# 995       431289  ...         1                       ?              87200
# 996       608177  ...         3                       ?             108480
# 997       442797  ...         3                     YES              67500
# 998       441714  ...         1                     YES              46980
# 999       612260  ...         3                       ?               5060
#
#     injury_claim property_claim  vehicle_claim   auto_make auto_model  \
# 0           6510          13020          52080        Saab        92x
# 1            780            780           3510    Mercedes       E400
# 2           7700           3850          23100       Dodge        RAM
# 3           6340           6340          50720   Chevrolet      Tahoe
# 4           1300            650           4550      Accura        RSX
# ..           ...            ...            ...         ...        ...
# 995        17440           8720          61040       Honda     Accord
# 996        18080          18080          72320  Volkswagen     Passat
# 997         7500           7500          52500      Suburu    Impreza
# 998         5220           5220          36540        Audi         A5
# 999          460            920           3680    Mercedes       E400
#
#     auto_year fraud_reported
# 0        2004              Y
# 1        2007              Y
# 2        2007              N
# 3        2014              Y
# 4        2009              N
# ..        ...            ...
# 995      2006              N
# 996      2015              N
# 997      1996              N
# 998      1998              N
# 999      2007              N
#
# [1000 rows x 39 columns]

# %%
con_cols=[]
for col in ic_df.columns:
    if ic_df[col].dtype=='int64' or ic_df[col].dtype=='float64':
        con_cols.append(col)
con_cols
# Out:
# ['months_as_customer',
#  'age',
#  'policy_number',
#  'policy_deductable',
#  'policy_annual_premium',
#  'umbrella_limit',
#  'insured_zip',
#  'capital-gains',
#  'capital-loss',
#  'incident_hour_of_the_day',
#  'number_of_vehicles_involved',
#  'bodily_injuries',
#  'witnesses',
#  'total_claim_amount',
#  'injury_claim',
#  'property_claim',
#  'vehicle_claim',
#  'auto_year']

# %%
import matplotlib.pyplot as plt

plt.boxplot(ic_df['months_as_customer'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c97f21b970>,
#   <matplotlib.lines.Line2D at 0x2c97f21bd00>],
#  'caps': [<matplotlib.lines.Line2D at 0x2c97f2300a0>,
#   <matplotlib.lines.Line2D at 0x2c97f230400>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2c97f21b610>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c97f230760>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c97f230ac0>],
#  'means': []}

# %%
plt.boxplot(ic_df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c97f297400>,
#   <matplotlib.lines.Line2D at 0x2c97f297760>],
#  'caps': [<matplotlib.lines.Line2D at 0x2c97f297ac0>,
#   <matplotlib.lines.Line2D at 0x2c97f297e20>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2c97f2970a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c97f2a21c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c97f2a2520>],
#  'means': []}

# %%
#list of all the input variables which are correlated with the output column

cor-cat_cols=[] #chi-square
cor_con_cols=[] #ANOVA

cor_cat_cols+cor_con_cols
